# %%
# Dataset distribution for flight_info.csv
import pandas as pd

# Read CSV file
df = pd.read_csv("flight_info.csv")

# Cancellations by airline
print(df["Carrier Code"].value_counts())

# Cancellations by airport
print(df["Origin"].value_counts())

# Cancellations by month
print(df["Month"].value_counts())
# Out:
# Carrier Code
# AA    617
# NK    170
# F9    115
# AS     46
# Name: count, dtype: int64
# Origin
# DFW    401
# ORD    148
# LGA    134
# BOS    126
# EWR     83
# SFO     56
# Name: count, dtype: int64
# Month
# 1     446
# 2     304
# 12    198
# Name: count, dtype: int64
